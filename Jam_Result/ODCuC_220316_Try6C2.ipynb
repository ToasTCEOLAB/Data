# %% [markdown]
# <a href="https://colab.research.google.com/github/NewTAs/ODCuC/blob/main/ODCuC_220316_Try6C2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import re
import glob
import cv2
import numpy as np
from sklearn.model_selection import train_test_split

import tensorflow as tf

from google.colab import drive
drive.mount('Lee_dataset')
# Out:
# Mounted at Lee_dataset

# %%
numberOfClass = 2
pictureWeightHeightSize = 224

train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
        '/content/Lee_dataset/MyDrive/CNNDATA/220314/Train/',
        target_size=(pictureWeightHeightSize, pictureWeightHeightSize),
        batch_size=numberOfClass,
        class_mode='categorical')

test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(
        '/content/Lee_dataset/MyDrive/CNNDATA/220314/Test/',
        target_size=(pictureWeightHeightSize, pictureWeightHeightSize),    
        batch_size=numberOfClass,
        class_mode='categorical')
# Out:
# Found 178 images belonging to 2 classes.
# Found 62 images belonging to 2 classes.

# %%
"""
Recall and Declare Convolutional Neural Network Models.

Using CNN Models: VGG19, ResNet50V2, ResNet152V2, InceptionResNetV2
"""

# from tensorflow.keras.applications import VGG19
# from tensorflow.keras.applications import ResNet50V2
# from tensorflow.keras.applications import InceptionResNetV2
# from tensorflow.keras.applications import ResNet152V2

from tensorflow.keras.applications import InceptionV3

# %%
"""
Learning four models using repetitive statements without interruption.
"""

model = InceptionV3(include_top=True, weights=None, input_shape=(224, 224, 3), pooling=max, classes=numberOfClass)
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')
model.fit(train_generator, epochs=100, validation_data = test_generator)

score = model.evaluate(test_generator)[1] * 100
print(f'0 -- Evaluate -- : {score:.2f}')
print(score)

model.save("/content/Lee_dataset/MyDrive/CNNDATA/Result/6C_InceptionV3")

# for i in range(4):
#     if i == 0:
#         model = VGG19(include_top=True, weights=None, input_shape=(224, 224, 3), pooling=max, classes=numberOfClass)
#     elif i == 1:
#         model = ResNet50V2(include_top=True, weights=None, input_shape=(224, 224, 3), pooling=max, classes=numberOfClass)
#     elif i == 2:
#         model = InceptionResNetV2(include_top=True, weights=None, input_shape=(224, 224, 3), pooling=max, classes=numberOfClass)
#     else:
#         model = ResNet152V2(include_top=True, weights=None, input_shape=(224, 224, 3), pooling=max, classes=numberOfClass)
    
#     model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')
#     model.fit(train_generator, epochs=100, validation_data = test_generator)
    
#     score = model.evaluate(test_generator)[1] * 100
#     print(f'{i} -- Evaluate -- : {score:.2f}')
#     print(score)

#     if i == 0:
#       model.save("/content/Lee_dataset/MyDrive/CNNDATA/Result/6C_VGG_Model")
#     elif i == 1:
#       model.save("/content/Lee_dataset/MyDrive/CNNDATA/Result/6C_ResNet50V2_Model")
#     elif i == 2:
#       model.save("/content/Lee_dataset/MyDrive/CNNDATA/Result/6C_InceptionResNetV2")
#     else:
#       model.save("/content/Lee_dataset/MyDrive/CNNDATA/Result/6C_ResNet152V2")
# Out:
# Epoch 1/100
# 89/89 [==============================] - 64s 511ms/step - loss: 1.2404 - accuracy: 0.4888 - val_loss: 0.8415 - val_accuracy: 0.5161
# Epoch 2/100
# 89/89 [==============================] - 5s 57ms/step - loss: 0.7152 - accuracy: 0.6180 - val_loss: 2.0005 - val_accuracy: 0.4839
# Epoch 3/100
# 89/89 [==============================] - 5s 56ms/step - loss: 0.8537 - accuracy: 0.5843 - val_loss: 6.0788 - val_accuracy: 0.4839
# Epoch 4/100
# 89/89 [==============================] - 5s 57ms/step - loss: 0.8044 - accuracy: 0.5843 - val_loss: 0.7485 - val_accuracy: 0.5323
# Epoch 5/100
# 89/89 [==============================] - 5s 56ms/step - loss: 0.6535 - accuracy: 0.6180 - val_loss: 1.4474 - val_accuracy: 0.4194
# Epoch 6/100
# 89/89 [==============================] - 5s 56ms/step - loss: 0.6772 - accuracy: 0.6348 - val_loss: 1.5714 - val_accuracy: 0.5968
# Epoch 7/100
# 89/89 [==============================] - 5s 56ms/step - loss: 0.7112 - accuracy: 0.5899 - val_loss: 0.6548 - val_accuracy: 0.7097
# Epoch 8/100
# 89/89 [==============================] - 5s 58ms/step - loss: 0.5522 - accuracy: 0.7584 - val_loss: 1.4188 - val_accuracy: 0.6452
# Epoch 9/100
# 89/89 [==============================] - 5s 57ms/step - loss: 0.5438 - accuracy: 0.7584 - val_loss: 1.8877 - val_accuracy: 0.5000
# Epoch 10/100
# 89/89 [==============================] - 5s 56ms/step - loss: 0.5878 - accuracy: 0.6910 - val_loss: 0.8365 - val_accuracy: 0.6613
# Epoch 11/100
# 89/89 [==============================] - 5s 56ms/step - loss: 0.6316 - accuracy: 0.6629 - val_loss: 0.9617 - val_accuracy: 0.6290
# Epoch 12/100
# 89/89 [==============================] - 5s 57ms/step - loss: 0.5498 - accuracy: 0.7528 - val_loss: 0.6571 - val_accuracy: 0.6774
# Epoch 13/100
# 89/89 [==============================] - 5s 56ms/step - loss: 0.6142 - accuracy: 0.6966 - val_loss: 0.6771 - val_accuracy: 0.6290
# Epoch 14/100
# 89/89 [==============================] - 5s 56ms/step - loss: 0.5539 - accuracy: 0.7697 - val_loss: 6.6391 - val_accuracy: 0.5645
# Epoch 15/100
# 89/89 [==============================] - 5s 55ms/step - loss: 0.7271 - accuracy: 0.6124 - val_loss: 0.8078 - val_accuracy: 0.4839
# Epoch 16/100
# 89/89 [==============================] - 5s 57ms/step - loss: 0.5957 - accuracy: 0.6798 - val_loss: 1.0987 - val_accuracy: 0.5484
# Epoch 17/100
# 89/89 [==============================] - 5s 56ms/step - loss: 0.4914 - accuracy: 0.7865 - val_loss: 1.8626 - val_accuracy: 0.5323
# Epoch 18/100
# 89/89 [==============================] - 5s 56ms/step - loss: 0.5978 - accuracy: 0.6854 - val_loss: 1.1006 - val_accuracy: 0.5645
# Epoch 19/100
# 89/89 [==============================] - 5s 56ms/step - loss: 0.5735 - accuracy: 0.6854 - val_loss: 0.6392 - val_accuracy: 0.6935
# Epoch 20/100
# 89/89 [==============================] - 5s 56ms/step - loss: 0.5926 - accuracy: 0.7247 - val_loss: 64.1244 - val_accuracy: 0.4839
# Epoch 21/100
# 89/89 [==============================] - 5s 56ms/step - loss: 0.6261 - accuracy: 0.7079 - val_loss: 0.7157 - val_accuracy: 0.6613
# Epoch 22/100
# 89/89 [==============================] - 5s 56ms/step - loss: 0.5594 - accuracy: 0.7416 - val_loss: 0.8827 - val_accuracy: 0.5645
# Epoch 23/100
# 89/89 [==============================] - 5s 57ms/step - loss: 0.6369 - accuracy: 0.7079 - val_loss: 1.2352 - val_accuracy: 0.5968
# Epoch 24/100
# 89/89 [==============================] - 5s 57ms/step - loss: 0.5555 - accuracy: 0.7528 - val_loss: 1.9699 - val_accuracy: 0.5806
# Epoch 25/100
# 89/89 [==============================] - 5s 57ms/step - loss: 0.5502 - accuracy: 0.7247 - val_loss: 0.4687 - val_accuracy: 0.8065
# Epoch 26/100
# 89/89 [==============================] - 5s 56ms/step - loss: 0.4366 - accuracy: 0.8202 - val_loss: 0.6294 - val_accuracy: 0.7419
# Epoch 27/100
# 89/89 [==============================] - 5s 56ms/step - loss: 0.6358 - accuracy: 0.7135 - val_loss: 0.5629 - val_accuracy: 0.7581
# Epoch 28/100
# 89/89 [==============================] - 5s 56ms/step - loss: 0.5467 - accuracy: 0.7472 - val_loss: 5.1688 - val_accuracy: 0.5000
# Epoch 29/100
# 89/89 [==============================] - 5s 57ms/step - loss: 0.4559 - accuracy: 0.7978 - val_loss: 7.7905 - val_accuracy: 0.5161
# Epoch 30/100
# 89/89 [==============================] - 5s 55ms/step - loss: 0.5761 - accuracy: 0.6798 - val_loss: 32.9077 - val_accuracy: 0.5484
# Epoch 31/100
# 89/89 [==============================] - 5s 55ms/step - loss: 0.5741 - accuracy: 0.7472 - val_loss: 0.8497 - val_accuracy: 0.7742
# Epoch 32/100
# 89/89 [==============================] - 5s 55ms/step - loss: 0.4620 - accuracy: 0.7809 - val_loss: 1.3061 - val_accuracy: 0.6452
# Epoch 33/100
# 89/89 [==============================] - 5s 55ms/step - loss: 0.3878 - accuracy: 0.8483 - val_loss: 0.3454 - val_accuracy: 0.8710
# Epoch 34/100
# 89/89 [==============================] - 5s 55ms/step - loss: 0.5160 - accuracy: 0.7416 - val_loss: 0.5144 - val_accuracy: 0.7742
# Epoch 35/100
# 89/89 [==============================] - 5s 56ms/step - loss: 0.4138 - accuracy: 0.8202 - val_loss: 0.8613 - val_accuracy: 0.6613
# Epoch 36/100
# 89/89 [==============================] - 5s 56ms/step - loss: 0.4155 - accuracy: 0.8090 - val_loss: 0.5820 - val_accuracy: 0.7742
# Epoch 37/100
# 89/89 [==============================] - 5s 56ms/step - loss: 0.2915 - accuracy: 0.8933 - val_loss: 0.4596 - val_accuracy: 0.7419
# Epoch 38/100
# 89/89 [==============================] - 5s 56ms/step - loss: 0.2501 - accuracy: 0.8989 - val_loss: 1.9820 - val_accuracy: 0.4839
# Epoch 39/100
# 89/89 [==============================] - 5s 56ms/step - loss: 0.3494 - accuracy: 0.8539 - val_loss: 1.0834 - val_accuracy: 0.7742
# Epoch 40/100
# 89/89 [==============================] - 5s 56ms/step - loss: 0.3575 - accuracy: 0.8652 - val_loss: 1.5994 - val_accuracy: 0.5806
# Epoch 41/100
# 89/89 [==============================] - 5s 56ms/step - loss: 0.3922 - accuracy: 0.8483 - val_loss: 0.8619 - val_accuracy: 0.8710
# Epoch 42/100
# 89/89 [==============================] - 5s 55ms/step - loss: 0.2614 - accuracy: 0.9045 - val_loss: 1.6102 - val_accuracy: 0.6935
# Epoch 43/100
# 89/89 [==============================] - 5s 55ms/step - loss: 0.2525 - accuracy: 0.8989 - val_loss: 0.3167 - val_accuracy: 0.8548
# Epoch 44/100
# 89/89 [==============================] - 5s 56ms/step - loss: 0.2101 - accuracy: 0.9213 - val_loss: 0.7141 - val_accuracy: 0.7581
# Epoch 45/100
# 89/89 [==============================] - 5s 56ms/step - loss: 0.2167 - accuracy: 0.9157 - val_loss: 0.4807 - val_accuracy: 0.8226
# Epoch 46/100
# 89/89 [==============================] - 5s 57ms/step - loss: 0.1320 - accuracy: 0.9551 - val_loss: 1.0270 - val_accuracy: 0.6452
# Epoch 47/100
# 89/89 [==============================] - 5s 56ms/step - loss: 0.3182 - accuracy: 0.8876 - val_loss: 0.4002 - val_accuracy: 0.7903
# Epoch 48/100
# 89/89 [==============================] - 5s 56ms/step - loss: 0.3020 - accuracy: 0.8989 - val_loss: 0.3544 - val_accuracy: 0.9032
# Epoch 49/100
# 89/89 [==============================] - 5s 55ms/step - loss: 0.1385 - accuracy: 0.9382 - val_loss: 1.1592 - val_accuracy: 0.5968
# Epoch 50/100
# 89/89 [==============================] - 5s 55ms/step - loss: 0.1541 - accuracy: 0.9494 - val_loss: 0.2663 - val_accuracy: 0.9194
# Epoch 51/100
# 89/89 [==============================] - 5s 54ms/step - loss: 0.2081 - accuracy: 0.9270 - val_loss: 2.1706 - val_accuracy: 0.7097
# Epoch 52/100
# 89/89 [==============================] - 5s 56ms/step - loss: 0.2679 - accuracy: 0.9157 - val_loss: 10.1786 - val_accuracy: 0.6129
# Epoch 53/100
# 89/89 [==============================] - 5s 55ms/step - loss: 0.2329 - accuracy: 0.9045 - val_loss: 0.5342 - val_accuracy: 0.7258
# Epoch 54/100
# 89/89 [==============================] - 5s 56ms/step - loss: 0.1703 - accuracy: 0.9157 - val_loss: 1.4618 - val_accuracy: 0.7258
# Epoch 55/100
# 89/89 [==============================] - 5s 55ms/step - loss: 0.2021 - accuracy: 0.9270 - val_loss: 0.1877 - val_accuracy: 0.9194
# Epoch 56/100
# 89/89 [==============================] - 5s 55ms/step - loss: 0.0674 - accuracy: 0.9831 - val_loss: 1.4216 - val_accuracy: 0.7097
# Epoch 57/100
# 89/89 [==============================] - 5s 56ms/step - loss: 0.2351 - accuracy: 0.9213 - val_loss: 0.5110 - val_accuracy: 0.7258
# Epoch 58/100
# 89/89 [==============================] - 5s 55ms/step - loss: 0.1533 - accuracy: 0.9494 - val_loss: 0.2403 - val_accuracy: 0.9194
# Epoch 59/100
# 89/89 [==============================] - 5s 55ms/step - loss: 0.1236 - accuracy: 0.9663 - val_loss: 0.4279 - val_accuracy: 0.9032
# Epoch 60/100
# 89/89 [==============================] - 5s 56ms/step - loss: 0.0680 - accuracy: 0.9719 - val_loss: 0.5459 - val_accuracy: 0.8710
# Epoch 61/100
# 89/89 [==============================] - 5s 55ms/step - loss: 0.3553 - accuracy: 0.8764 - val_loss: 10.4225 - val_accuracy: 0.5323
# Epoch 62/100
# 89/89 [==============================] - 5s 56ms/step - loss: 0.3839 - accuracy: 0.8258 - val_loss: 1.4135 - val_accuracy: 0.5806
# Epoch 63/100
# 89/89 [==============================] - 5s 55ms/step - loss: 0.1320 - accuracy: 0.9494 - val_loss: 0.3159 - val_accuracy: 0.8710
# Epoch 64/100
# 89/89 [==============================] - 5s 55ms/step - loss: 0.1633 - accuracy: 0.9494 - val_loss: 4.1102 - val_accuracy: 0.5645
# Epoch 65/100
# 89/89 [==============================] - 5s 56ms/step - loss: 0.1338 - accuracy: 0.9551 - val_loss: 0.5585 - val_accuracy: 0.7097
# Epoch 66/100
# 89/89 [==============================] - 5s 55ms/step - loss: 0.2373 - accuracy: 0.9101 - val_loss: 8.8514 - val_accuracy: 0.5161
# Epoch 67/100
# 89/89 [==============================] - 5s 56ms/step - loss: 0.2157 - accuracy: 0.9101 - val_loss: 0.5521 - val_accuracy: 0.7742
# Epoch 68/100
# 89/89 [==============================] - 5s 56ms/step - loss: 0.0796 - accuracy: 0.9607 - val_loss: 0.2156 - val_accuracy: 0.9355
# Epoch 69/100
# 89/89 [==============================] - 5s 56ms/step - loss: 0.0144 - accuracy: 1.0000 - val_loss: 0.2969 - val_accuracy: 0.9194
# Epoch 70/100
# 89/89 [==============================] - 5s 56ms/step - loss: 0.0891 - accuracy: 0.9551 - val_loss: 0.5797 - val_accuracy: 0.8710
# Epoch 71/100
# 89/89 [==============================] - 5s 56ms/step - loss: 0.0224 - accuracy: 0.9944 - val_loss: 0.1366 - val_accuracy: 0.9516
# Epoch 72/100
# 89/89 [==============================] - 5s 55ms/step - loss: 0.0682 - accuracy: 0.9775 - val_loss: 0.6711 - val_accuracy: 0.8387
# Epoch 73/100
# 89/89 [==============================] - 5s 56ms/step - loss: 0.0915 - accuracy: 0.9719 - val_loss: 0.2858 - val_accuracy: 0.8871
# Epoch 74/100
# 89/89 [==============================] - 5s 55ms/step - loss: 0.2210 - accuracy: 0.9438 - val_loss: 22.1987 - val_accuracy: 0.6935
# Epoch 75/100
# 89/89 [==============================] - 5s 55ms/step - loss: 0.2777 - accuracy: 0.8933 - val_loss: 1.5467 - val_accuracy: 0.6774
# Epoch 76/100
# 89/89 [==============================] - 5s 55ms/step - loss: 0.2469 - accuracy: 0.8933 - val_loss: 0.3124 - val_accuracy: 0.8710
# Epoch 77/100
# 89/89 [==============================] - 5s 56ms/step - loss: 0.0458 - accuracy: 0.9888 - val_loss: 0.3209 - val_accuracy: 0.9032
# Epoch 78/100
# 89/89 [==============================] - 5s 55ms/step - loss: 0.0483 - accuracy: 0.9775 - val_loss: 0.3187 - val_accuracy: 0.8871
# Epoch 79/100
# 89/89 [==============================] - 5s 57ms/step - loss: 0.0099 - accuracy: 1.0000 - val_loss: 0.2481 - val_accuracy: 0.9194
# Epoch 80/100
# 89/89 [==============================] - 5s 55ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.2966 - val_accuracy: 0.9194
# Epoch 81/100
# 89/89 [==============================] - 5s 56ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.3244 - val_accuracy: 0.9194
# Epoch 82/100
# 89/89 [==============================] - 5s 55ms/step - loss: 0.6266 - accuracy: 0.7416 - val_loss: 64.5053 - val_accuracy: 0.4516
# Epoch 83/100
# 89/89 [==============================] - 5s 55ms/step - loss: 0.3454 - accuracy: 0.8708 - val_loss: 9.6980 - val_accuracy: 0.5484
# Epoch 84/100
# 89/89 [==============================] - 5s 56ms/step - loss: 0.1949 - accuracy: 0.9213 - val_loss: 0.7022 - val_accuracy: 0.5968
# Epoch 85/100
# 89/89 [==============================] - 5s 55ms/step - loss: 0.0964 - accuracy: 0.9719 - val_loss: 0.2326 - val_accuracy: 0.9194
# Epoch 86/100
# 89/89 [==============================] - 5s 56ms/step - loss: 0.1230 - accuracy: 0.9607 - val_loss: 0.2778 - val_accuracy: 0.8871
# Epoch 87/100
# 89/89 [==============================] - 5s 55ms/step - loss: 0.0499 - accuracy: 0.9888 - val_loss: 0.2972 - val_accuracy: 0.8710
# Epoch 88/100
# 89/89 [==============================] - 5s 56ms/step - loss: 0.0110 - accuracy: 1.0000 - val_loss: 0.3814 - val_accuracy: 0.8871
# Epoch 89/100
# 89/89 [==============================] - 5s 55ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.4174 - val_accuracy: 0.8871
# Epoch 90/100
# 89/89 [==============================] - 5s 55ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.3193 - val_accuracy: 0.9032
# Epoch 91/100
# 89/89 [==============================] - 5s 55ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.3522 - val_accuracy: 0.9194
# Epoch 92/100
# 89/89 [==============================] - 5s 56ms/step - loss: 0.0076 - accuracy: 1.0000 - val_loss: 0.6018 - val_accuracy: 0.9032
# Epoch 93/100
# 89/89 [==============================] - 5s 55ms/step - loss: 0.0364 - accuracy: 0.9944 - val_loss: 0.4427 - val_accuracy: 0.9355
# Epoch 94/100
# 89/89 [==============================] - 5s 55ms/step - loss: 0.1672 - accuracy: 0.9551 - val_loss: 0.9350 - val_accuracy: 0.8226
# Epoch 95/100
# 89/89 [==============================] - 5s 56ms/step - loss: 0.0428 - accuracy: 0.9831 - val_loss: 0.5216 - val_accuracy: 0.9032
# Epoch 96/100
# 89/89 [==============================] - 5s 56ms/step - loss: 0.0141 - accuracy: 1.0000 - val_loss: 0.3432 - val_accuracy: 0.9194
# Epoch 97/100
# 89/89 [==============================] - 5s 56ms/step - loss: 0.0240 - accuracy: 0.9888 - val_loss: 0.2375 - val_accuracy: 0.9032
# Epoch 98/100
# 89/89 [==============================] - 5s 56ms/step - loss: 0.2060 - accuracy: 0.9045 - val_loss: 3.3156 - val_accuracy: 0.7419
# Epoch 99/100
# 89/89 [==============================] - 5s 55ms/step - loss: 0.1465 - accuracy: 0.9494 - val_loss: 0.1685 - val_accuracy: 0.9677
# Epoch 100/100
# 89/89 [==============================] - 5s 55ms/step - loss: 0.2143 - accuracy: 0.9101 - val_loss: 0.3322 - val_accuracy: 0.8387
# 31/31 [==============================] - 1s 30ms/step - loss: 0.3322 - accuracy: 0.8387
# 0 -- Evaluate -- : 83.87
# 83.87096524238586
# INFO:tensorflow:Assets written to: /content/Lee_dataset/MyDrive/CNNDATA/Result/6C_InceptionV3/assets
