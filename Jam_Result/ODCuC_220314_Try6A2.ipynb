# %% [markdown]
# <a href="https://colab.research.google.com/github/NewTAs/ODCuC/blob/main/ODCuC_220314_Try6A2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import re
import glob
import cv2
import numpy as np
from sklearn.model_selection import train_test_split

import tensorflow as tf

from google.colab import drive
drive.mount('Lee_dataset')
# Out:
# Drive already mounted at Lee_dataset; to attempt to forcibly remount, call drive.mount("Lee_dataset", force_remount=True).

# %%
numberOfClass = 2
pictureWeightHeightSize = 224

train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
        '/content/Lee_dataset/MyDrive/CNNDATA/Train/',
        target_size=(pictureWeightHeightSize, pictureWeightHeightSize),
        batch_size=numberOfClass,
        class_mode='categorical')

test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(
        '/content/Lee_dataset/MyDrive/CNNDATA/Test/',
        target_size=(pictureWeightHeightSize, pictureWeightHeightSize),    
        batch_size=numberOfClass,
        class_mode='categorical')
# Out:
# Found 140 images belonging to 2 classes.
# Found 58 images belonging to 2 classes.

# %%
"""
Recall and Declare Convolutional Neural Network Models.

Using CNN Models: VGG19, ResNet50V2, ResNet152V2, InceptionResNetV2
"""

# from tensorflow.keras.applications import VGG19
# from tensorflow.keras.applications import ResNet50V2
# from tensorflow.keras.applications import InceptionResNetV2
# from tensorflow.keras.applications import ResNet152V2
from tensorflow.keras.applications import InceptionV3

# %%
"""
Learning four models using repetitive statements without interruption.
"""
model = InceptionV3(include_top=True, weights=None, input_shape=(224, 224, 3), pooling=max, classes=numberOfClass)
# for i in range(4):
#     if i == 0:
#         model = VGG19(include_top=True, weights=None, input_shape=(224, 224, 3), pooling=max, classes=numberOfClass)
#     elif i == 1:
#         model = ResNet50V2(include_top=True, weights=None, input_shape=(224, 224, 3), pooling=max, classes=numberOfClass)
#     elif i == 2:
#         model = InceptionResNetV2(include_top=True, weights=None, input_shape=(224, 224, 3), pooling=max, classes=numberOfClass)
#     else:
#         model = ResNet152V2(include_top=True, weights=None, input_shape=(224, 224, 3), pooling=max, classes=numberOfClass)
    
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')
model.fit(train_generator, epochs=100, validation_data = test_generator)
    
score = model.evaluate(test_generator)[1] * 100
print(f'0 -- Evaluate -- : {score:.2f}')
print(score)

model.save("/content/Lee_dataset/MyDrive/CNNDATA/Result/6A2_InceptionV3_Model")
    # if i == 0:
    #   model.save("/content/Lee_dataset/MyDrive/CNNDATA/Result/6A_VGG_Model_300")
    # elif i == 1:
    #   model.save("/content/Lee_dataset/MyDrive/CNNDATA/Result/6A_ResNet50V2_Model_300")
    # elif i == 2:
    #   model.save("/content/Lee_dataset/MyDrive/CNNDATA/Result/6A_InceptionResNetV2_300")
    # else:
    #   model.save("/content/Lee_dataset/MyDrive/CNNDATA/Result/6A_ResNet152V2_300")
# Out:
# Epoch 1/100
# 70/70 [==============================] - 62s 719ms/step - loss: 1.6496 - accuracy: 0.5500 - val_loss: 1.1206 - val_accuracy: 0.4828
# Epoch 2/100
# 70/70 [==============================] - 9s 124ms/step - loss: 0.7905 - accuracy: 0.6071 - val_loss: 1.2385 - val_accuracy: 0.5172
# Epoch 3/100
# 70/70 [==============================] - 9s 124ms/step - loss: 0.7685 - accuracy: 0.6643 - val_loss: 0.7077 - val_accuracy: 0.5345
# Epoch 4/100
# 70/70 [==============================] - 9s 125ms/step - loss: 0.6542 - accuracy: 0.7214 - val_loss: 0.9273 - val_accuracy: 0.4828
# Epoch 5/100
# 70/70 [==============================] - 9s 125ms/step - loss: 0.3499 - accuracy: 0.9000 - val_loss: 1.8254 - val_accuracy: 0.5172
# Epoch 6/100
# 70/70 [==============================] - 9s 125ms/step - loss: 0.3758 - accuracy: 0.8286 - val_loss: 3.2288 - val_accuracy: 0.4828
# Epoch 7/100
# ...
